# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\LENOVO\Desktop\Movie-Rating.csv')

# %%
df
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(df)
# Out:
# 559

# %%
numpy.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 numpy.__version__
#
# NameError: name 'numpy' is not defined

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
df.shape
# Out:
# (559, 6)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
df.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
df.columns = ['Film', 'Genre','CriticRating','AudienceRating','BudgetMillions','Year']

# %%
df.head(1)
# Out:
#                     Film   Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer   Comedy            87              81
#
#    BudgetMillions  Year
# 0               8  2009

# %%
df.shape
# Out:
# (559, 6)

# %%
df.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
df.Film = df.Film.astype('category')
df.Genre = df.Genre.astype('category')
df.Year = df.Year.astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
df.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline #ALL THE PLOT SHOULD INSIDE THE LINE

import warnings
warnings.filterwarnings('ignore') #Filterwarning is used to ignore the OS updates error issues
# Out:
# UsageError: unrecognized arguments: #ALL THE PLOT SHOULD INSIDE THE LINE

# %%
j = sns.jointplot(data =df, x = 'CriticRating', y= 'AudienceRating')

# %%
j = sns.jointplot(data =df, x = 'CriticRating', y= 'AudienceRating', kind= 'scatter')

# %%
j = sns.jointplot(data =df, x = 'CriticRating', y= 'AudienceRating', kind= 'hex')

# %%
j = sns.jointplot(data =df, x = 'CriticRating', y= 'AudienceRating', kind= 'kde')

# %%
m1 = sns.distplot(df.AudienceRating)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1168\4200230641.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   m1 = sns.distplot(df.AudienceRating)

# %%
m1 = sns.distplot(df.CriticRating)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1168\4100664612.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   m1 = sns.distplot(df.CriticRating)

# %%
m1 = sns.displot(df.CriticRating)

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.distplot(df.AudienceRating, bins=10)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1168\2847074245.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   m2 = sns.distplot(df.AudienceRating, bins=10)

# %%
sns.set_style('white')
m3 = sns.distplot(df.AudienceRating, bins=10)
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1168\2340229847.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   m3 = sns.distplot(df.AudienceRating, bins=10)

# %%
z = sns.violinplot(data=df, x='Genre', y='CriticRating')

# %%
w1 = sns.boxplot(data=df[df.Genre == 'Drama'], x='Year', y='AudienceRating') #Genre Attribute is comparing a Drama

# %%
#Creating facet grid

# %%
g = sns.FacetGrid(df, row = 'Genre', col = 'Year', hue = 'Genre') #kind of subplots

# %%
plt.scatter(df.CriticRating,df.AudienceRating)

# %%
g = sns.FacetGrid(df, row = 'Genre' , col = 'Year', hue= 'Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating')

# %%
g = sns.FacetGrid(df, row = 'Genre' , col = 'Year', hue= 'Genre')
g = g.map(plt.hist, 'BudgetMillions')

# %%
FINAL DISCUSSION WHAT WE LEARN SO FAR---
1. Categories datatype in python 
2. jointplots
3. histogram
4. stacked histograms #one graph inner other graph
5. kde plot
6. subplot
7. violin plots
8. factet grid
9. how to rename a column
10. how to drop 
11. : slicing applied in data frame
