# %% [markdown]
# # 2nd MINI PROJECT FOR VISUALIZATION BY USING PANDAS,OPENPYXL,NUMPY,MATPLOTLIB,SEABORN.

# %%
import openpyxl
import pandas as pd

workbook = openpyxl.Workbook()
sheet = workbook.active

data = [
    ['NAME','DOMAIN','AGE','LOCATION','SALARY','EXP'],
    ['ALEX','TESTING',25,'BNG',5000,2],
    ['BARAB','ML',35,'VIJ',3000,3],
    ['UDAY','DESIGNER',35,'HYD',3000,2],
    ['VIKAS','AI',35,'CHI',30010,6]
]


for row in data:
    sheet.append(row)
workbook.save('data.xlsx')

# %%
data
# Out:
# [['NAME', 'DOMAIN', 'AGE', 'LOCATION', 'SALARY', 'EXP'],
#  ['ALEX', 'TESTING', 25, 'BNG', 5000, 2],
#  ['BARAB', 'ML', 35, 'VIJ', 3000, 3],
#  ['UDAY', 'DESIGNER', 35, 'HYD', 3000, 2],
#  ['VIKAS', 'AI', 35, 'CHI', 30010, 6]]

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\LENOVO'

# %%
emp = pd.read_excel(r'C:\Users\LENOVO\data.xlsx')
emp
# Out:
#     NAME    DOMAIN  AGE LOCATION  SALARY  EXP
# 0   ALEX   TESTING   25      BNG    5000    2
# 1  BARAB        ML   35      VIJ    3000    3
# 2   UDAY  DESIGNER   35      HYD    3000    2
# 3  VIKAS        AI   35      CHI   30010    6

# %%
emp.shape
# Out:
# (4, 6)

# %%
emp.columns
# Out:
# Index(['NAME', 'DOMAIN', 'AGE', 'LOCATION', 'SALARY', 'EXP'], dtype='object')

# %%
len(emp.columns)
# Out:
# 6

# %%
len(emp.row) # we can't use row we have default in it see below line
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13488\3340134882.py in ?()
# ----> 1 len(emp.row)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'row'

# %%
len(emp)
# Out:
# 4

# %%
emp['SALARY']
# Out:
# 0     5000
# 1     3000
# 2     3000
# 3    30010
# Name: SALARY, dtype: int64

# %%
import numpy as np              # for ND Array
import matplotlib.pyplot as plt # for visualization
import seaborn as sns      # for statistic visualization

# %%
vis1 = sns.displot(emp['SALARY'])

# %%
vis2 = sns.distplot(emp['SALARY'])
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_13488\826855712.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   vis2 = sns.distplot(emp['SALARY'])

# %%
vis3 = plt.hist(emp['SALARY'])

# %%
emp
# Out:
#     NAME    DOMAIN  AGE LOCATION  SALARY  EXP
# 0   ALEX   TESTING   25      BNG    5000    2
# 1  BARAB        ML   35      VIJ    3000    3
# 2   UDAY  DESIGNER   35      HYD    3000    2
# 3  VIKAS        AI   35      CHI   30010    6

# %%
plt.rcParams['figure.figsize'] = 1,1

# %%
vis5 = sns.lmplot(data=emp, x = 'EXP', y ='SALARY')

# %%
vis5 = sns.lmplot(data =  emp, x = 'EXP', y = 'SALARY', fit_reg = False) # we want to disable line in graph then we use False

# %%
vis6 = sns.lmplot(data=emp, x='EXP', y='SALARY', fit_reg= True) # if we place Ture then we get line.

# %%
emp
# Out:
#     NAME    DOMAIN  AGE LOCATION  SALARY  EXP
# 0   ALEX   TESTING   25      BNG    5000    2
# 1  BARAB        ML   35      VIJ    3000    3
# 2   UDAY  DESIGNER   35      HYD    3000    2
# 3  VIKAS        AI   35      CHI   30010    6
